# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-28ccaaac-8291-48bd-81b4-779fe4531025" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-28ccaaac-8291-48bd-81b4-779fe4531025">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import os
os.listdir()
# Out:
# ['.config', 'archive (4).zip', 'sample_data']

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-e7d42f21-bd07-40ad-a9ec-3dfd659fa077" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e7d42f21-bd07-40ad-a9ec-3dfd659fa077">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
gender_breakdown = pd.crosstab(df['Cluster'], df['Genre'], normalize='index') * 100
gender_breakdown.round(1)
# Out:
# Genre    Female  Male
# Cluster
# 0          83.3  16.7
# 1          90.7   9.3
# 2          73.1  26.9
# 3          17.6  82.4
# 4          16.3  83.7

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

sns.barplot(x=cluster_summary.index, y=cluster_summary['Age'], ax=axes[0], palette='viridis')
axes[0].set_title('Average Age per Cluster')

sns.barplot(x=cluster_summary.index, y=cluster_summary['Annual Income (k$)'], ax=axes[1], palette='viridis')
axes[1].set_title('Average Income per Cluster')

sns.barplot(x=cluster_summary.index, y=cluster_summary['Spending Score (1-100)'], ax=axes[2], palette='viridis')
axes[2].set_title('Average Spending Score per Cluster')

plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_1107/2273500622.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cluster_summary.index, y=cluster_summary['Age'], ax=axes[0], palette='viridis')
# /tmp/ipykernel_1107/2273500622.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=cluster_summary.index, y=cluster_summary['Annual Income (k$)'], ax=axes[1], palette='viridis')
# /tmp/ipykernel_1107/2273500622.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
persona_map = {
    0: 'Young Enthusiasts',
    1: 'Average Customers',
    2: 'Cautious Seniors',
    3: 'High-Value Trendsetters',
    4: 'Affluent Conservatives'
}

df['Persona'] = df['Cluster'].map(persona_map)
df.head(10)
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
# 5           6  Female   22                  17                      76
# 6           7  Female   35                  18                       6
# 7           8  Female   23                  18                      94
# 8           9    Male   64                  19                       3
# 9          10  Female   30                  19                      72
#
#    Cluster            Persona
# 0        1  Average Customers
# 1        0  Young Enthusiasts
# 2        1  Average Customers
# 3        0  Young Enthusiasts
# 4        1  Average Customers
# ...

# %%
df.to_csv('customer_segments_final.csv', index=False)

from google.colab import files
files.download('customer_segments_final.csv')

# %%
import zipfile
import os

with zipfile.ZipFile("archive (4).zip", 'r') as zip_ref:
    zip_ref.extractall("mall_data")

os.listdir("mall_data")
# Out:
# ['Mall_Customers.csv']

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

sns.set(style="whitegrid")

df = pd.read_csv("mall_data/Mall_Customers.csv")
df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age                     200 non-null    int64
#  3   Annual Income (k$)      200 non-null    int64
#  4   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(1)
# memory usage: 7.9+ KB

# %%
df.describe()
# Out:
#        CustomerID         Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000  200.000000          200.000000              200.000000
# mean   100.500000   38.850000           60.560000               50.200000
# std     57.879185   13.969007           26.264721               25.823522
# min      1.000000   18.000000           15.000000                1.000000
# 25%     50.750000   28.750000           41.500000               34.750000
# 50%    100.500000   36.000000           61.500000               50.000000
# 75%    150.250000   49.000000           78.000000               73.000000
# max    200.000000   70.000000          137.000000               99.000000

# %%
fig, axes = plt.subplots(1, 3, figsize=(15, 4))

sns.histplot(df['Age'], bins=15, kde=True, ax=axes[0])
axes[0].set_title('Age Distribution')

sns.histplot(df['Annual Income (k$)'], bins=15, kde=True, ax=axes[1])
axes[1].set_title('Annual Income Distribution')

sns.histplot(df['Spending Score (1-100)'], bins=15, kde=True, ax=axes[2])
axes[2].set_title('Spending Score Distribution')

plt.tight_layout()
plt.show()

# %%
sns.countplot(x='Genre', data=df)
plt.title('Gender Distribution')
plt.show()

# %%
sns.pairplot(df[['Age', 'Annual Income (k$)', 'Spending Score (1-100)']])
plt.show()

# %%
plt.figure(figsize=(8, 6))
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', data=df)
plt.title('Annual Income vs Spending Score')
plt.show()

# %%
df_processed = df.drop('CustomerID', axis=1)

# Genre ko encode karo (Male=0, Female=1 ya vice versa)
df_processed['Genre'] = df_processed['Genre'].map({'Male': 0, 'Female': 1})

df_processed.head()
# Out:
#    Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0      0   19                  15                      39
# 1      0   21                  15                      81
# 2      1   20                  16                       6
# 3      1   23                  16                      77
# 4      1   31                  17                      40

# %%
features = ['Genre', 'Age', 'Annual Income (k$)', 'Spending Score (1-100)']
X = df_processed[features]

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

X_scaled[:5]  # pehle 5 rows scaled form mein dekhne ke liye
# Out:
# array([[-1.12815215, -1.42456879, -1.73899919, -0.43480148],
#        [-1.12815215, -1.28103541, -1.73899919,  1.19570407],
#        [ 0.88640526, -1.3528021 , -1.70082976, -1.71591298],
#        [ 0.88640526, -1.13750203, -1.70082976,  1.04041783],
#        [ 0.88640526, -0.56336851, -1.66266033, -0.39597992]])

# %%
pca_full = PCA()
pca_full.fit(X_scaled)

explained_variance = pca_full.explained_variance_ratio_
cumulative_variance = np.cumsum(explained_variance)

plt.figure(figsize=(8, 5))
plt.plot(range(1, len(cumulative_variance) + 1), cumulative_variance, marker='o')
plt.axhline(y=0.95, color='r', linestyle='--', label='95% threshold')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('PCA - Explained Variance')
plt.legend()
plt.grid(True)
plt.show()

print("Explained variance per component:", explained_variance)
print("Cumulative variance:", cumulative_variance)
# Out:
# Explained variance per component: [0.33690046 0.26230645 0.23260639 0.16818671]
# Cumulative variance: [0.33690046 0.5992069  0.83181329 1.        ]

# %%
pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_scaled)

print("Shape after PCA:", X_pca.shape)
print("Variance explained by 2 components:", sum(pca.explained_variance_ratio_))

X_pca[:5]
# Out:
# Shape after PCA: (200, 2)
# Variance explained by 2 components: 0.5992069019819846
# array([[-0.40638272, -0.52071363],
#        [-1.42767287, -0.3673102 ],
#        [ 0.05076057, -1.89406774],
#        [-1.6945131 , -1.63190805],
#        [-0.31310838, -1.81048272]])

# %%
wcss = []
K_range = range(1, 11)

for k in K_range:
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42, n_init=10)
    kmeans.fit(X_pca)
    wcss.append(kmeans.inertia_)

plt.figure(figsize=(8, 5))
plt.plot(K_range, wcss, marker='o')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('WCSS')
plt.title('Elbow Method')
plt.grid(True)
plt.show()

# %%
silhouette_scores = []
K_range_sil = range(2, 11)  # silhouette ke liye minimum 2 clusters chahiye

for k in K_range_sil:
    kmeans = KMeans(n_clusters=k, init='k-means++', random_state=42, n_init=10)
    labels = kmeans.fit_predict(X_pca)
    score = silhouette_score(X_pca, labels)
    silhouette_scores.append(score)

plt.figure(figsize=(8, 5))
plt.plot(K_range_sil, silhouette_scores, marker='o', color='orange')
plt.xlabel('Number of Clusters (K)')
plt.ylabel('Silhouette Score')
plt.title('Silhouette Score Method')
plt.grid(True)
plt.show()

print("Silhouette scores:", list(zip(K_range_sil, silhouette_scores)))
# Out:
# Silhouette scores: [(2, np.float64(0.40139995663275646)), (3, np.float64(0.3886771378798135)), (4, np.float64(0.4164156778177507)), (5, np.float64(0.3877934284115026)), (6, np.float64(0.3940420055325302)), (7, np.float64(0.3805953283030303)), (8, np.float64(0.3643338867205296)), (9, np.float64(0.3662683490615449)), (10, np.float64(0.38346444842179694))]

# %%
optimal_k = 5

kmeans_final = KMeans(n_clusters=optimal_k, init='k-means++', random_state=42, n_init=10)
cluster_labels = kmeans_final.fit_predict(X_pca)

# Original dataframe mein cluster label wapas add karo
df_processed['Cluster'] = cluster_labels
df['Cluster'] = cluster_labels

df.head()
# Out:
#    CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40
#
#    Cluster
# 0        1
# 1        0
# 2        1
# 3        0
# 4        1

# %%
df['Cluster'].value_counts().sort_index()
# Out:
# Cluster
# 0    48
# 1    43
# 2    26
# 3    34
# 4    49
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 7))
scatter = plt.scatter(X_pca[:, 0], X_pca[:, 1], c=cluster_labels, cmap='viridis', s=60, alpha=0.8)
centers = kmeans_final.cluster_centers_
plt.scatter(centers[:, 0], centers[:, 1], c='red', marker='X', s=200, label='Centroids')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('Customer Segments (PCA Space)')
plt.legend()
plt.colorbar(scatter, label='Cluster')
plt.show()

# %%
plt.figure(figsize=(10, 7))
sns.scatterplot(x='Annual Income (k$)', y='Spending Score (1-100)', hue='Cluster', data=df, palette='viridis', s=80)
plt.title('Customer Segments (Income vs Spending Score)')
plt.show()

# %%
cluster_summary = df.groupby('Cluster').agg({
    'Age': 'mean',
    'Annual Income (k$)': 'mean',
    'Spending Score (1-100)': 'mean',
    'CustomerID': 'count'
}).rename(columns={'CustomerID': 'Count'})

cluster_summary = cluster_summary.round(1)
cluster_summary
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)  Count
# Cluster
# 0        26.7                49.9                    73.4     48
# 1        39.7                49.6                    43.7     43
# 2        55.4                43.8                    24.1     26
# 3        29.9                81.5                    73.9     34
# 4        47.4                75.0                    30.6     49
